# %%
def N__logistic(N_0, r, k, time):
    # Logistic growth model
    N_values = [N_0]
    current_N = N_0
    for _ in range(time):
        # Calculate next population size using the logistic equation
        current_N = current_N + r * current_N * (1 - current_N / k)
        # Round to 3 decimal places
        current_N = round(current_N, 3)
        N_values.append(current_N)
    return N_values

# %%
#Run the function with 365 days and r =0.6 and k = 400 with an initial population of 0.12
result = N__logistic(12, 0.6, 400, 365)
print(result)
# Out:
# [12, 18.984, 29.834, 46.399, 71.009, 106.051, 152.811, 209.471, 269.336, 322.125, 359.753, 381.471, 392.073, 396.735, 398.678, 399.469, 399.787, 399.915, 399.966, 399.986, 399.994, 399.998, 399.999, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 4
# ...

# %%
import matplotlib.pyplot as plt

# %%
# plot the results with days on the x-axis and population size on the y-axis


days = list(range(366)) # 0 to 365 days
plt.plot(days, result, marker='o')
plt.title('Population Growth Over Time')
plt.xlabel('Days')
plt.ylabel('Population Size')
plt.grid()
plt.show()

# %%
def N__logistic(N_0, r, k, time):
    # Logistic growth model
    N_values = [N_0]
    current_N = N_0
    for _ in range(time):
        # Calculate next population size using the logistic equation
        current_N = current_N + r * current_N * (1 - current_N / k)
        # Round to 3 decimal places
        current_N = round(current_N, 3)
        N_values.append(current_N)
    return N_values

# %%
#Run the function with 35 days and r =0.6 and k = 400 with an initial population of 0.12
result = N__logistic(12, 0.6, 400, 35)
print(result)
# Out:
# [12, 18.984, 29.834, 46.399, 71.009, 106.051, 152.811, 209.471, 269.336, 322.125, 359.753, 381.471, 392.073, 396.735, 398.678, 399.469, 399.787, 399.915, 399.966, 399.986, 399.994, 399.998, 399.999, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0, 400.0]

# %%
import matplotlib.pyplot as plt

# %%
# plot the results with days on the x-axis and population size on the y-axis

days = list(range(len(result)))  # Match the length of result
plt.plot(days, result, marker='o')
plt.title('Population Growth Over Time')
plt.xlabel('Days')
plt.ylabel('Population Size')
plt.grid()
plt.show()

# %%
result = N__logistic(12, 1, 400, 35)  # simulate for 35 days

# Find the first day when population reaches or exceeds carrying capacity
for day, carrying_capacity in enumerate(result):
    if carrying_capacity >= 400:
        print(f"The plot is filled on day {day} with a population of {carrying_capacity}.")
        break
else:
    print("The plot was not filled within the simulated days.")
# Out:
# The plot is filled on day 9 with a population of 400.0.
